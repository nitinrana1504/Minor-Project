# %%
# !pip install bing-image-downloader

# %%
# !mkdir Bulldog

# %%
from bing_image_downloader import downloader
downloader.download("bulldog", limit = 200,output_dir='Bulldog')
# Out:
# [%] Downloading Images to D:\miniProject\Bulldog\bulldog
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://animalsbreeds.com/wp-content/uploads/2015/01/Bulldog-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.britannica.com/78/232778-050-D3701AB1/English-bulldog-dog.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://3.bp.blogspot.com/-hzr_z54HYxg/VPHdQc98dgI/AAAAAAAADzI/b8rYhvDu5lM/s1600/English-Bulldog.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://estesphoto.files.wordpress.com/2010/05/blog_img_7773.jpg
# [Error]Invalid image, not saving http://estesphoto.files.wordpress.com/2010/05/blog_img_7773.jpg
#
# [!] Issue getting: http://estesphoto.files.wordpress.com/2010/05/blog_img_7773.jpg
# [!] Error:: Invalid image, not saving http://estesphoto.files.wordpress.com/2010/05/blog_img_7773.jpg
#
# ...
