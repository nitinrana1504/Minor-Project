# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from keras.preprocessing import image

# %%
model = load_model('dog_modelv3.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
test_image = image.load_img('Manual_Testing/Doberman.jpg', target_size=(256, 256))
test_image_array = image.img_to_array(test_image)
test_image_array = test_image_array / 255.0
test_image_array = np.expand_dims(test_image_array, axis=0) 
result = model.predict(test_image_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step

# %%
Breed_Name = ['Bull Dog', 'Doberman', 'German Shepherd', 'Golden Retriever', 'Husky', 'Pariah Dog', 'Rottweilers']
print("Class Probabilities:", result[0])
# Out:
# Class Probabilities: [1.3207590e-06 9.9999225e-01 5.9589520e-06 1.0166927e-09 1.3767671e-08
#  5.4465848e-10 4.4324852e-07]

# %%
Breed_Name = ['Bull Dog', 'Doberman', 'German Shepherd', 'Golden Retriever', 'Husky', 'Pariah Dog', 'Rottweilers']
print("Class Probabilities:", result[0])
predicted_Breed = np.argmax(result[0])
predicted_label = Breed_Name[predicted_Breed]
print("Predicted Class Label:", predicted_label)
for i, Probability in enumerate(result[0]):
    print(f"Class {Breed_Name[i]}: {Probability:.6f}")

print(f"Predicted Class Label: {predicted_label}")
# Out:
# Class Probabilities: [1.3207590e-06 9.9999225e-01 5.9589520e-06 1.0166927e-09 1.3767671e-08
#  5.4465848e-10 4.4324852e-07]
# Predicted Class Label: Doberman
# Class Bull Dog: 0.000001
# Class Doberman: 0.999992
# Class German Shepherd: 0.000006
# Class Golden Retriever: 0.000000
# Class Husky: 0.000000
# Class Pariah Dog: 0.000000
# Class Rottweilers: 0.000000
# Predicted Class Label: Doberman

# %%
plt.imshow(test_image)
plt.title(f'Prediction: {predicted_label} ({result[0][predicted_Breed]*100:.6f}%)', fontsize=14)
plt.show()

# %%
images = ['Manual_Testing/Bull_Dog.jpg','Manual_Testing/Doberman.jpg','Manual_Testing/German_Shepherd.jpg','Manual_Testing/Golden_Retriever.jpg','Manual_Testing/Husky.png','Manual_Testing/Pariah.jpg','Manual_Testing/Rottweiler.jpg']

# %%
for i in images:
    test_image = image.load_img(i, target_size=(256, 256))
    test_image_array = image.img_to_array(test_image)
    test_image_array = test_image_array / 255.0
    test_image_array = np.expand_dims(test_image_array, axis=0) 
    result = model.predict(test_image_array)
    Breed_Name = ['Bull Dog', 'Doberman', 'German Shepherd', 'Golden Retriever', 'Husky', 'Pariah Dog', 'Rottweilers']
    predicted_Breed = np.argmax(result[0])
    predicted_label = Breed_Name[predicted_Breed]

    for i, Probability in enumerate(result[0]):
        print(f"Class {Breed_Name[i]}: {Probability:.6f}")
    plt.imshow(test_image)
    plt.title(f'Prediction: {predicted_label} ({result[0][predicted_Breed]*100:.6f}%)', fontsize=14)
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Class Bull Dog: 0.995927
# Class Doberman: 0.000001
# Class German Shepherd: 0.000001
# Class Golden Retriever: 0.004064
# Class Husky: 0.000002
# Class Pariah Dog: 0.000006
# Class Rottweilers: 0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Class Bull Dog: 0.000001
# Class Doberman: 0.999992
# Class German Shepherd: 0.000006
# Class Golden Retriever: 0.000000
# Class Husky: 0.000000
# Class Pariah Dog: 0.000000
# Class Rottweilers: 0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# Class Bull Dog: 0.000002
# Class Doberman: 0.000001
# Class German Shepherd: 0.999997
# Class Golden Retriever: 0.000000
# Class Husky: 0.000000
# Class Pariah Dog: 0.000000
# Class Rottweilers: 0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Class Bull Dog: 0.000003
# Class Doberman: 0.000000
# Class German Shepherd: 0.000000
# Class Golden Retriever: 0.999997
# Class Husky: 0.000000
# Class Pariah Dog: 0.000000
# Class Rottweilers: 0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Class Bull Dog: 0.000363
# Class Doberman: 0.000000
# Class German Shepherd: 0.000796
# Class Golden Retriever: 0.000000
# Class Husky: 0.998789
# Class Pariah Dog: 0.000052
# Class Rottweilers: 0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Class Bull Dog: 0.002826
# Class Doberman: 0.000035
# Class German Shepherd: 0.000122
# Class Golden Retriever: 0.009808
# Class Husky: 0.000054
# Class Pariah Dog: 0.987155
# Class Rottweilers: 0.000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# Class Bull Dog: 0.000000
# Class Doberman: 0.000207
# Class German Shepherd: 0.000008
# Class Golden Retriever: 0.000000
# Class Husky: 0.000000
# Class Pariah Dog: 0.000000
# Class Rottweilers: 0.999784
